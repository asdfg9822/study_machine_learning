# %%
import tensorflow as tf

W = tf.Variable(tf.random_uniform([1],-1.5,1.5))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y-y_data))
optimizer = tf.train.GradientDescentOptimizer(0.0013)
train = optimizer.minimize(loss)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in xrange(12):
  _,w_val,b_val,loss_val=sess.run([train,W,b,loss])
  print(w_val,b_val,loss_val)
  
  plt.plot(x_data,y_data,'ro')
  plt.plot(x_data,w_val*x_data + b_val)
  plt.xlabel('x')
  plt.ylabel('y')
  plt.legend()
  plt.show()
# Out:
# (array([ 1044.79504395], dtype=float32), array([ 50.18314362], dtype=float32), 4.1229402e+08)
# (array([ 997.91174316], dtype=float32), array([ 47.69612503], dtype=float32), 9312284.0)
# (array([ 1000.02484131], dtype=float32), array([ 47.57017136], dtype=float32), 8502484.0)
# (array([ 999.94152832], dtype=float32), array([ 47.33841705], dtype=float32), 8500819.0)
# (array([ 999.95672607], dtype=float32), array([ 47.11145401], dtype=float32), 8500775.0)
# (array([ 999.96746826], dtype=float32), array([ 46.88431549], dtype=float32), 8500735.0)
# (array([ 999.97839355], dtype=float32), array([ 46.65722656], dtype=float32), 8500696.0)
# (array([ 999.98937988], dtype=float32), array([ 46.4301796], dtype=float32), 8500655.0)
# (array([ 1000.00030518], dtype=float32), array([ 46.20317459], dtype=float32), 8500617.0)
# (array([ 1000.01123047], dtype=float32), array([ 45.97620773], dtype=float32), 8500577.0)
# (array([ 1000.02215576], dtype=float32), array([ 45.74928284], dtype=float32), 8500536.0)
# (array([ 1000.03308105], dtype=float32), array([ 45.5223999], dtype=float32), 8500498.0)

# %%
import   numpy   as   np 
num_points   =   200 
vectors_set   =   []

for   i   in   xrange(num_points):
      x   =   np.random.normal(5,5)+15
      y   =      x*1000+   (np.random.normal(0,3))*1000       
      vectors_set.append([x,y])
x_data   =   [v[0]   for   v   in   vectors_set   ] 
y_data   =   [v[1]   for   v   in   vectors_set   ]

import   matplotlib.pyplot   as   plt 
plt.plot(x_data,y_data,'ro') 
plt.ylim([0,40000]) 
plt.xlim([0,35])
plt.xlabel('x') 
plt.ylabel('y') 
plt.legend() 
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
